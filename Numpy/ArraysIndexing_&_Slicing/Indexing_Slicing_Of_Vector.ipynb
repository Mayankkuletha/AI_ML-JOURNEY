# %%
import numpy as np

arr = np.arange(11,20)
print(arr)
# Out:
# [11 12 13 14 15 16 17 18 19]

# %%
# Indexing
#Indexing works same as lists
arr[2]
arr[0]
# Out:
# np.int64(11)

# %%
# Slicing
# arr_slice = arr[3:8] #Will exclude last one
# arr_slice=arr[:] #full array
arr_slice=arr[:5] #Take zero index as default 
arr_slice = arr[0:6:2] #means from 0 to 5 and gap of two mtlb ki do do chodke steps lega
print(arr_slice)
# Out:
# [11 13 15]
