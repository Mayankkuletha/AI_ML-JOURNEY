# %%
import numpy as np

a = np.array([[1,2],[3,4]])
b=np.array([[5,6],[7,8]])
print(a)
print(b)
# Out:
# [[1 2]
#  [3 4]]
# [[5 6]
#  [7 8]]

# %%
# multiplication of matrix

a @ b

#OR 

np.dot(a,b)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
# Transpose
transpose = a.T
print(transpose)
# Out:
# [[1 3]
#  [2 4]]
