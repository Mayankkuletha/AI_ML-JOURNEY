# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = np.linspace(0,5,11)
x
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# PLot -- > plot is used to create a linegraph.
# values should always be equal 

plt.plot(x,y)
# Title of graph
plt.title("Hello Graph")
# label for x axis
plt.xlabel("X axis")
# label for y axis
plt.ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')
