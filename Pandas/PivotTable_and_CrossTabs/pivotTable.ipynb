# %%
import numpy as np
import pandas as pd

data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South',
               'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South',
               'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice',
            'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

print(df)
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    835     55   John  January      Q1
# 1  2023-01-02       B   West    924     97   Mary  January      Q1
# 2  2023-01-03       C  North    632     49    Bob  January      Q1
# 3  2023-01-04       D  South    323     12  Alice  January      Q1
# 4  2023-01-05       A   East    613     54   John  January      Q1
# 5  2023-01-06       B   West    207     97   Mary  January      Q1
# 6  2023-01-07       C  North    130     82    Bob  January      Q1
# 7  2023-01-08       D  South    157     29  Alice  January      Q1
# 8  2023-01-09       A   East    696     48   John  January      Q1
# 9  2023-01-10       B   West    405     38   Mary  January      Q1
# 10 2023-01-11       C  North    440     95    Bob  January      Q1
# 11 2023-01-12       D  South    861     70  Alice  January      Q1
# 12 2023-01-13       A   East    521     93   John  January      Q1
# 13 2023-01-14       B   West    807     44   Mary  January      Q1
# 14 2023-01-15       C  North    209     76    Bob  January      Q1
# 15 2023-01-16       D  South    627     75  Alice  January      Q1
# 16 2023-01-17       A   East    430     19   John  January      Q1
# 17 2023-01-18       B   West    948     94   Mary  January      Q1
# 18 2023-01-19       C  North    275     96    Bob  January      Q1
# 19 2023-01-20       D  South    926     51  Alice  January      Q1

# %%
# Creating Pivot Table
# When we want to create table according to your values 
# By default it provide mean of all vaules but we can change them by giving aggregrate functions
pd.pivot_table(df,values="Sales",index="Region",columns="Product") 
pd.pivot_table(df,values="Sales",index="Region",columns="Product" , aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     385.0    NaN    NaN    NaN
# North      NaN    NaN  530.0    NaN
# South      NaN    NaN    NaN  638.0
# West       NaN  807.0    NaN    NaN

# %%
# you can give multiple values

pivot2 = pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     441.6    NaN    NaN    NaN  38.6   NaN   NaN   NaN
# North      NaN    NaN  567.8    NaN   NaN   NaN  66.4   NaN
# South      NaN    NaN    NaN  531.6   NaN   NaN   NaN  39.2
# West       NaN  680.4    NaN    NaN   NaN  52.6   NaN   NaN
